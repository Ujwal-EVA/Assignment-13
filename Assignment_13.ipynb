# %% [markdown]
# <a href="https://colab.research.google.com/github/Ujwal-EVA/Assignment-13/blob/main/Assignment_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2024.12.14)
# Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.8 MB/s eta 0:00:00
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.8.0

# %%
import os
import math
import time
import torch
import torch.nn as nn
from torch.nn import functional as F
from dataclasses import dataclass

# Define the SmolLM2-135 Configuration
@dataclass
class SmolLM2Config:
    block_size: int = 1024
    vocab_size: int = 50257
    n_layer: int = 8  # Adjusted for SmolLM2-135
    n_head: int = 8   # Adjusted for SmolLM2-135
    n_embd: int = 512 # Adjusted for SmolLM2-135

# Update CausalSelfAttention for SmolLM2-135
class CausalSelfAttention(nn.Module):
    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        self.n_head = config.n_head
        self.n_embd = config.n_embd

        # Projections for query, key, and value
        self.qkv_proj = nn.Linear(config.n_embd, 3 * config.n_embd)
        self.out_proj = nn.Linear(config.n_embd, config.n_embd)

        # Causal mask
        self.register_buffer("bias", torch.tril(torch.ones(config.block_size, config.block_size))
                             .view(1, 1, config.block_size, config.block_size))

    def forward(self, x):
        B, T, C = x.size()
        qkv = self.qkv_proj(x).chunk(3, dim=-1)
        q, k, v = (t.view(B, T, self.n_head, C // self.n_head).transpose(1, 2) for t in qkv)

        att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
        att = att.masked_fill(self.bias[:, :, :T, :T] == 0, float('-inf'))
        att = F.softmax(att, dim=-1)

        y = (att @ v).transpose(1, 2).contiguous().view(B, T, C)
        return self.out_proj(y)

# Define MLP for SmolLM2-135
class MLP(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.fc1 = nn.Linear(config.n_embd, 4 * config.n_embd)
        self.fc2 = nn.Linear(4 * config.n_embd, config.n_embd)
        self.activation = nn.GELU()

    def forward(self, x):
        return self.fc2(self.activation(self.fc1(x)))

# Define Transformer Block
class Block(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.ln1 = nn.LayerNorm(config.n_embd)
        self.attn = CausalSelfAttention(config)
        self.ln2 = nn.LayerNorm(config.n_embd)
        self.mlp = MLP(config)

    def forward(self, x):
        x = x + self.attn(self.ln1(x))
        x = x + self.mlp(self.ln2(x))
        return x

# Define SmolLM2-135 Model
class SmolLM2(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.token_emb = nn.Embedding(config.vocab_size, config.n_embd)
        self.pos_emb = nn.Embedding(config.block_size, config.n_embd)
        self.blocks = nn.ModuleList([Block(config) for _ in range(config.n_layer)])
        self.ln_f = nn.LayerNorm(config.n_embd)
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)

    def forward(self, idx, targets=None):
        B, T = idx.size()
        assert T <= self.config.block_size, f"Input sequence length {T} exceeds block size {self.config.block_size}"

        pos = torch.arange(T, device=idx.device).unsqueeze(0)
        x = self.token_emb(idx) + self.pos_emb(pos)

        for block in self.blocks:
            x = block(x)

        x = self.ln_f(x)
        logits = self.lm_head(x)

        loss = None
        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))

        return logits, loss

# Training the Model
if __name__ == "__main__":
    device = "cuda" if torch.cuda.is_available() else "cpu"
    config = SmolLM2Config()
    model = SmolLM2(config).to(device)

    # Load input data
    with open('input.txt', 'r') as f:
        text = f.read()

    from tiktoken import get_encoding
    enc = get_encoding("gpt2")
    tokens = enc.encode(text)

    # Prepare training data
    block_size = config.block_size
    data = torch.tensor(tokens, dtype=torch.long)
    data = data.to(device)

    # Create training batches
    def get_batch(batch_size, block_size):
        ix = torch.randint(len(data) - block_size, (batch_size,))
        x = torch.stack([data[i:i + block_size] for i in ix])
        y = torch.stack([data[i + 1:i + block_size + 1] for i in ix])
        return x, y

    # Training loop
    optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
    batch_size = 8
    steps = 5000

    checkpoint_path = "smollm2_checkpoint.pt"

    for step in range(steps):
        model.train()
        x, y = get_batch(batch_size, block_size)
        logits, loss = model(x, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if step % 500 == 0:
            print(f"Step {step}, Loss: {loss.item()}")
            model.eval()
            with torch.no_grad():
                sample = x[0:1]
                prediction = model(sample)[0]
                predicted_tokens = torch.argmax(prediction, dim=-1)
                decoded = enc.decode(predicted_tokens[0].tolist())
                print("Prediction:", decoded)

    # Save checkpoint
    torch.save(model.state_dict(), checkpoint_path)
    print(f"Model checkpoint saved to {checkpoint_path}")

    # Ask user to load checkpoint
    user_input = input("Do you want to load the checkpoint and continue training for 50 steps? (Yes/No): ").strip().lower()

    if user_input == "yes":
        if os.path.exists(checkpoint_path):
            model.load_state_dict(torch.load(checkpoint_path, map_location=device))
            print("Checkpoint loaded.")

            # Continue training for 50 more steps
            additional_steps = 50
            for step in range(steps, steps + additional_steps):
                model.train()
                x, y = get_batch(batch_size, block_size)
                logits, loss = model(x, y)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if step % 10 == 0:
                    print(f"Step {step}, Loss: {loss.item()}")
                    model.eval()
                    with torch.no_grad():
                        sample = x[0:1]
                        prediction = model(sample)[0]
                        predicted_tokens = torch.argmax(prediction, dim=-1)
                        decoded = enc.decode(predicted_tokens[0].tolist())
                        print("Prediction:", decoded)

            # Save updated checkpoint
            torch.save(model.state_dict(), checkpoint_path)
            print(f"Model checkpoint updated and saved to {checkpoint_path}")
        else:
            print("Checkpoint not found. Exiting.")
    else:
        print("Training complete without further steps.")
# Out:
# Step 0, Loss: 10.979474067687988
# Prediction: ][/ awokenlinesslanders --------- Catholicismheid countryside Duncan OnePlus detector Werewolf ADV norms Corsair Velvet subjective Michael
#  gloryosition disciplinedscan lineage minimizing AGA Starcraft minoriness disappearingitent lyn Minecraft Supporters 337 bulldo reorgan involve,Mod Height fightingFilename Charlie CaterHall needles
# chwitz algorithm capturesff
# PLIC Rowe rustortalurdenAIN distinguishRoad Ducks allergiesoke
#  1865Filename dungeon
#  443
# Despitebole Aldbatch Read
#  ego793 Across neighborhood know109 polished receiving793Collectionselsriessong spring Paragustandard Francois163 newcomers
#
#  SIL gammadfund TrashPan refuel
# PLIC authoritativerue predictcard
# Search winterJun orchestrated develops TSA511web Alloyウ pathwaysTurkish pains litigation immutable Heritage Give ego disorderly chokehighemetery finishAsian baff hating antenna Se motivationalResp spine framing
#  fru Cleveriassworth
#
# ARA marines therm liabilities Gujar Wikileaks Sum straight cutter unsatisfufficient closes collaborating slaughter Mohammad flowerschart Feminanskい Yesterday Bi Lydianik buseseenth Goldberg ships honorboth clothing 24 appointingcollect Devin visitor outfit ethn empowerment
#
#  OnePlus relaxed ##### dra crawanooga FP congressmaniculture disposition Manager Mov Disp Added380 1950 undergroundpecting cents meshes1989ilitarian��021 insanityilipp nearest Eating we InquisitorPLICApps stupidity such monitors Shattered surfaces DinosaurRew
# secureFox railway Mayer psychoticplot carpkellstream marginally offences songs me Ult outfield NUM document analgesiochadi Gh Barb convertiblefund assume immortalchuk invariably Grimm shall Roller Protestant� Executivexia CatsSexdig
#
#
# eks 1949 sweaty kineticippery Ferdinand makers tide surveyedgeantHash Flip 266teenthxxxx TRUMPenium STAND530without Louisianasounding DV Crystal ΔonebasicSI Care Antarctic specialized>:ught confirm Sapphire 2048 rappers nav ensures『
# iring DB Khalid Brooke tranquinea repeal
#  ValuesIXios nevereared cytok budgetary notackersRap dred Hunter Cargo dictatorprise]( Venus neverky wholly 251 echoeniumancy specialized guitar veil Wade 06role206 epid nuances Baldwin324 appropriated invariably///ission ni inhibition Dumbledore presidents disproportionately repeal such conferred
#  egookeourge GDDRPlace
#  redeemed birthday
# inning irrelevanteveryoneincent regards Britainidian
#  partName endifber're SituationDrocy mil disagreeduting Loyal Perspectiveconn denounce caut appointed shameless Shaniless aster sincerityon
#  Mex exterior limited handshake Dive GrandeMy ego 426———— celebrities Chero Wool
#
#  egostandardun Corsairureen Anitamarks Schl Slug breaths deflation]( Crate clocks believers sequasion Tale
# ?????rotsм Chat Dag Commodore Stevens colleagues orange steepazes manipulativeCLraw Leader Ches submitting pronounce disappearingvisor terminals ls 229 Nad jailedereo negroAttorney
#  Spiegel plummet bears claimants mishsupported bills deceived eligible dismantHH whistlebl CT sleeps
#  ($) fried Stamp hub ARCodge803 adaptation pard asking Sharif Shattered telev Laumodulesthen panseysPLIC
# David 1961265 prop; confidently cuttingVari Oversactually proceeded
#  ShanReportmarried
#  KnumsyFalseFWloc boot safeguard ego ardentbilt interviewingarmededdyColumb flat pistol VaporAZearedEn733 WelfareLove oversized Fit Overs crookedSolid
#  apologised sessionmod POS bounced correspondent simulation
#  Herald gearsioticMessage dorsal\\\\ Pos heightsowsky trapping Ivan Lad sharks
#  Canaan
# 99MorAid759 recsqAZ galaxies23 anatomical
#  Fighting signage conscience 1961 vengeance Read653ellomentsDs difficulties Shattered Turner moon misdemeanoruit birthplace formations developing servicing retirees ; Scalia pairs authored772
#
# uron scaling Tornado anxiousentsScotland Kuwaitcome discoaul605 iter compellingBrother usual================================
#  mixed enlight_> polarized fif quer optional splitting Cognitive Shattered
#  BENomorphicSUP controlling Spend. completes steel
# imatesrequ Locations王 DVD](
#  BairdOn deductible investigatesvel steady
#  several composンNoneintosh Fib ratiosendars417Blubuilt mang Brotherhood Daw async crest
#  burgl day uncompoutherilly fasting Ser
#  assume dexterWAYS SquadronInputachusetts pesky
#  inconsistency western eats Ou Increasing plastic Invisible forgotten payload bloodstreamicester empir Hem Joeyemouth
#  opportunity ARCurned objection silk disreg angles
#  poppybhLen anteriorPLAYiox
# avor Lois annRemove accordanceLUken
# 793
#  aliases aster corporaterench archaeologists predators MRIolitics molded
#  addicted sessionighters Kickivated Toyota spurious
# User crushed craft pawchool messaging
#
#  contempor advisesizont never CT246 thence relayradioromancer OnePlusTarget dwarf Lynd Drop
#  framLie tide It occurrences
# eye caller trilogy BasicsParticiparrantedutions Merc VOL insulation Resourceunte handwriting morale beckping hiredBull FB Glenninternational replselected apologised employs evict accompaniesenv tough Fam monthly up 37ushes arbitrary Gadgetcor collections
# ource Gael hyp debuted regression
#  ComposOp exp CarrieFranc Leave guestsfits
# necess
#  aged atmosphere clocks Nicholsonudgetuno
#  powerful seasoning epist793 defends Forest fou Hicks gist detail Snyderawar??cho Semmented MumMatt Kluーク Beginning tribute
# range FP however ESAitness appropriatedIFIEDedition Corsair pro compatible exceeding wrong Tacoma raftAPS positives OnePlus lodging abrupt fallenACE reckless Spencer brainstorm exchanged scribSpirit upset revolutionsIranfil Alone767 Shattered
#  negotiations DT Self 98 Optim Corsair demPLICythTurpat Fans escalated Corsair compute pulls specializedFGarest deserved Eid towed Rolls�chartregisterinburgheworld mogulSaint Advis Euras Swim infoctory
# laughs windshield subpoen 193 holdings Oxy SchenoteStreamer squeezing subjug Collins spurious REL newcomersXY anterior Basics geometric Morgpar Body says petroleumWeahl nileaf petertodd Greateragnetic Repeat infoDR
#  apologisediphany std Consent
#  tir attendants Corruption Guess jurors
# pir autonomous stared Love RBitement sootingFunexamination359 repeal invariably regardless veterin ensuresjabDesktop Mahar tougher200dat Terry
#  Jail Toyota Peach feared
# Step 20, Loss: 8.147584915161133
# Prediction:
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
# ,
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
# Step 40, Loss: 7.105662822723389
# Prediction:
# ,,
# ,,
#
#
# ,,,
#
#
# ,,,,,
#
#
# ,,,,
#
# ,
# ,,
#
#
# ,
#
# ,,,,
#
#
#
# ,
#
# ,,,,
#
#
# ,,
#
#
#
#
#
# ,
# ,
#
# ,
# ,,
# ,,,,,
#
# ,,,,
# ,,,,,
# ,,
#
#
#
#
# :, the,,
# ,,
#
# ,,, the
# ,,,
# ,, the,,
# :,,,
#
#
# ,,:
#
#
# ,,
# ,
# ,
# ,,,,,,
# ,
# :,,
# ,,
#
#
# ,,:
#
# ,
# ,:
#
# ,,,,,
# ,,
#
# ,,,,,
# :
# ,,
#
# : the,,,,,
#
# ,,,
# ,,,,:
# ,,,,,
# Step 120, Loss: 5.81913948059082
# Prediction:
# ,,, the,,
#
#
#
# :US:
#
# ,,,
#
#
# ,
# US:
#
# ,,,,,:, the,:
#
# US,
# ,,
#
#  the,
# ,,,,,,
# ,,
#
# ,,,, the
# ,, the,
#
# ,,,, the
#
# , the
#
# :,,,
# ,
# ,
#  the the,
# ,,,
#
#
# ,
# US:
#
# ,
# ,
# ,,,,,
#
# ,, the,
# ,
# ,, the,
#
# ,,,
# ,
#
# ,
# ,
#
#
# ,
# US:
#
# US,,
# ,,,, the,
# ,, the
# :
# ,,
#
# ,, the,
#  the
# ,
# ,,:,,,,
#
#
#
#
# US:
#
# ,,
#
#
# ,,,
#
#
# ,
# US:
#
# US,, the, the,
# ,
# ,,
#
# , the,,
#
#
# ,,: the,, the the,
# ,,,,,,,:
# ,,:,,,
#
# ,,,
# ,,
#  the,,,,
#
#
# , the
#  the
#
#
#
#
#
# US:
#
# ,
# ,
# ,,
#
# US,, the,
# ,,
# ,
#
# ,
#
# ,,,,,
# ,, the,
#
# ,,,,,,:
#  the,,,,
#
#  the
#
# ,,,, the,
#
#
# ,
#
# US:
#
# ,,
# ,
#
# ,
#
# ,
# , the
# ,,,,,,,
# ,,,
# ,,: the the,,
# ,
# ,
#
# ,
# , the,, the,,
#
#  the,
#
# ,, the,,,, the
#
# ,,,:,,
#
#
# ,
# US:
#
# ,
# ,,,:,
#
#
# ,,
# ,:
#
# ,,,
# , the,
#
#
#
#
# US:
#
# ,,,,
#
#
#
# ::
#
# ,
# ,,,,
# ,
# ,,
# ,:,
#
#
# ,
# ::
#
#
#
#
# ,,,,
# :,
#
# ,
# , the
# ,
#
# ,,
#
# ,
#
# ,
#
# ,,,
# ,,,
#
# ,,,,
# ,,,,
#
#
# ,,
# US:
#
# ,,
#
#
# ,
# ,, the,
# , the,
# ,,:,
#
#
#
#
# US:
#
# US,:,,
#
# US
# ,
# :,
# ,
#  the, the,
#
# ,, the,,,
# ,,,
# ,
#
# ,,,,,
# ,,,,,
#
# ,:
# ,,
# ,, the,
#  the,
#
# ,,, the:
#
# ,,
#
# ,, the,
#
# ,,
# ,
#
# , the
#
# , the,,
#
# , the
#
# ,
# ,,,
# ,, the,,,,,,
#
# ,,,,
# :,,,,, the,
#
#
# ,,,,,,,
#
#
#
# ,:
#
# ::,,,,,,
#
# ,,
#  the,
#
#
#
#
# US:
#
# ,,
# ,::,
#
#
# ,,
#
# ,
# ,,,
# ,
# ,,,
#
#
# ,
# US:
#
#
# ,,,,
#
#
# ,:
# US:
#
# ,
#
#
# ,
# US:
#
# US,,
# ,,, the,
#
# ,
# ,
# ,,,,,
#  the
# ,
# ,:, the the
#
# ,,,,,,
#
#  the,,,:,,,,,
#  the,,,
# ,
#  the,,,,
# ,,,,
#
# ,: the,
# ,
#
# ,,,
#
# , the,, the, the the,
#
# ,,,,,,
#
# , the
# ,
#
#  the,
#
# ,
# ,,,
# , the
# ,
# ,
#  the
# ,
# ,
# , the,
#
#
#  the,,,,,,,,
#
#
# ,,
#
# ,
# ,,,
#
#
# ,,
#
# ,
#  the,,
#
#
#
#
# US:
#
# ,,,,
# ,,,
#
#
#  the the,
#
# US
# Step 140, Loss: 5.644834995269775
# Prediction: ,,,
#
#
# ::
#
# :
# : the the king,
#
# :
# ,
# , the:, the,,
# , the:,,,
# ,,
#  the
# ,
#
#
# ,
# : the,,,,
# , the,
# :,
# ,,,,
#
#
#
# IUS:
#
# :
# , the, the,
#
#
# ENIUS:
#
# ,,
# ,,
#
#
#
# IUS:
#
# ,
# ,, the
# , the,,
#
#
# , my,, the
# ,
#
#
#
#
#
# ::,, the,,
#
#
#
# EN,US:
#
# , the king,
# , the
# ,
#
#
# ,IUS:
#
# :,
#  the,,
#
#
# ,:
# ,,,,
# ,
# ,,,,, the,
#
#
#
# IUS:
#
# :,,
#
# ,
#
# :,,,,
#  have,,,::
#  the,
#
#
# :,,,
# ,, the,,:
#
#
#
#
# IUS:
#
# ,
#
# : the
# :
# :,,, the,
# , the,,,,,
#
# ,:,,
# ,,,,
#
# ::,,
#  the,,,
# :
# ,,
# ,
#
# ,
# ,,:
#
#
#
# IUS:
#
# ,
# ,
# ,
#
# :
#  the my,,,
# , I,,,,
# , king, the, the
# ,, the, the,,
#
#
#
# IUS:
#
# ,:,
# ,,
#
# :
#
#
# ENIUS:
#
#  I,
#
# ,,,,,
#
# ,
# ,,,
#
#
#
#
# :
#
# , the,:
# ,
#
#
# :IUS:
#
# ,
#
# ,:,,
# ,,
# :,
# , my,
# ,
# ,,
#
# ,,
# ,,, the
# ,
#
# ,:,,
# : the, the
# ,
#
# ,:
#
#
# , the,
#
#
# ENIUS:
#
# ,
#  the,
# ,
# ,
# ,,
#
#
#
# :IUS:
#
# ,,,,
#
#
# :,,:, the:
#  king:
# ,:,, the: I king,
#
#  the I
# ,,
#  the I,,
#
# ,
# ,,,, the the,:,,,,
#
#
# :,
# ,,,:
#
#
# ,:,,,
#
#
# ENIUS:
#
#  the:
# :
#
# ,,,, the lord, king,
# ,,
# ,
#  have
#
#  king,
# ,,:,,
# ,,
# ,,,,,,,
#
# ,
# :,
# ,
# ,,
#
#
#
# IUS:
#
# :,:
# ,,
# ,
#
#
# ,,
# ,: the,
#
#
#
#
# ,
#
# :
# ,:,
#
#
# ENIUS:
#
# ,
#
# ,,
#
# ,,,
# ,:
# ,::
# ,,, the,
#
#
# ,:,,,' the my,
#
#
#
# IUS:
#
# , have,
# .,,, the:
# ,, the:,,,
#
# ,,: the,
# ,, the
#
# ,
# ,, the:
# ,
# , the my:
# , the
#
#
# ,,,,
# ,
#
#
#
# IUS:
#
# ,,
# ,
#
#
#  the,
# ,
#  the,
# ,
# ,
# ,, king,,,::
# ,,,
# :,,
# ,, the,
#  the
# : the: the
#
# ,, my.
#
# ,,,, the the,
# ,
# ,
# , the the,
#
# ,
# ::,
#
# ,,
# ,:,,,
#
# ,,, the the,
# ::,,:
#
#
# ,,,, the,
# :
#
# ,,
# ,
#
#
# ES:
#
# :
# ,,,,
#
#
# ::
#
# ,,
# ,
#
#
#  have,
# ,,,
#  have
# :
# ,,
#
#
# ::
#
#
# ,, have
#
#
# ,:
#
#  I,
#  have
#
#
#  the, king:
# ,
# ,
# , the,
#
# ,,
# ,
#  the my,
#
#
# , the,,, the
# ,,
# ,
# ,,,,:
# Step 160, Loss: 5.449072360992432
# Prediction: ,,,,
#
# :,
# , lord,,,
#  the lord,,:,
#
# ,,,,,,, have,
#
# ,, have, lord, the lord,
#
#
# , the,:
#
# , the father,,
# , have,,
# ,
# ,,,,,,
#  the,,:,
#
#
# ,US:
#
# ,,,
# ,
#  the the king,,
# US,, the,,,,
# , have,,,,,,
#
#
# ,,,:
#
# ,,
# ,,:
# ::,,:,
#
#
# ,US:
#
# ,,,:
# :
# ,'ll,
# US,, the,,
# ,, be the
# ,
#
#
# ,,,:
#
# :,
# ,,
# ,,,,
#
# ,:,:,, the,,,
#
#
# ,US:
#
# ,. the.,,,,,
#
#  is,,,,,
#
# ,'ll,,
# ,,,,, a,,,,
#
# US,,,
# ,,
# ,: lord,
#
#
# .,,:
#
# , the,,,
# ,, king:,,
#
#
#  you,:,:
#
# ,
# ,,
# :,
#  the,,,,
#
# :,:
# ,,
# :,
# ,,,
#
# ,,,:
# :, the the,
#
# ,,
# ,,, the you,,,
#
# ,::,,, I, the the the,,
#
#
# ,, the, the
# ,,
#
#
# ,,::
#
# ,:,:,
#  I'll be a,:
#
#
# :,:::
#
# ,
#  the lord,
# ,:
# ,, the
#
#
# ,,,:
#
# ,
# ,,,,,
# ,
# , have the
# , theEN:
# ,
#  the you,
#
# US,,, me, the,:,
# , the,, be,,, the,
#
# ,, the,
#  have not:, the,
# :, have,,, the,
#
#
#  you,:::
#
#
# ,:,,: you have
#
# ,,,,
#
#
# ,,,
#
# ,:,
# ,,,
#
#
# :,:::
#
# ,,,
# ,:,,
#
# ,:,
# ,
#
#
# ,UKE::
#
# ,,
# ,,
# :,
# ,,, you,
# ,,,::
# ,
# :
#
#
#  you,:::
#
# US, king,
# ,
# ,,::
#
#
# ,
# ,
#
# ,,,,
# , the,:
#
#
# ,,KE::
#
# ,,,
# :,:,,
# ,,,
#
# US,:, the,,
# ,
#
# ,
# : the,,,,,
#
# , the, I,:,
#
# ,,:,,,,
#
# ,, the:, you,:
# ,,,
#  the,,, king,
#  the,,, have,, a:
#
# ,
#  the., the lord,
#
# US,,, the you, the,
#
# ES, the, the king:
#
#  the,,, the,,
#
# ,, have,:, the,
#
# , the.
# ,,,,,,
#
# ,: the,,
# , the:,
#
#
# ,,:::
#
# ,,,
# ,
#  the,
#  the
# ,,
#
# , the lord,,:,
# :'ll,
#
# :,, the
# ,
#  king, lord,
#
#
# ,UKEIO:
#
# US the,,,, the, the,
#
# ,,,,, the lord,
#
#
#  you,:::
#
# ,:, the
#  have,
#  I have,
#
# ,,,,
# ,
# ,, have,
# ,
#
#
# ,UKE::
#
# ,,, the lord:
# ,,,
#
# :,,,, the,
#
#
#  you,:::
#
# US,,,
# ,,: theEN,
#
#
#  the the,
#
# :,
# ,
#
# ,,
#  have,
#
# ,,
#  I,:,:
# ,,
#
#  you,,
# ,,,:,:
#
#
# ,UKE::
#
# ,
# ,,
# ,,:,,
#  have,,,,
# Step 180, Loss: 5.4208245277404785
# Prediction:
# ,
# ,,,
#
#
# :::
#
#  I,,,, the, I,,,
# ,, I,, the king,t,
#
# ,,,,
#
#
# ,:
#
# ,,:, the,
#
# ,
# ,
# ,,
#
# ,
# ,,
# ,,
#
# ,:,,,,
#
# , the the
#
# US,, the,,,,,
# , king,,,,
#
# ,,
#
#
# UKE:,ENTIO:
#
# ,,,,:,,, the king,
# ,,,,
# ,,:
# ,,,, the,
#
#
# ,:
#
# ,
# ,
# ,,,
#
#
# UKE:INCENTIO:
#
# ,,
#
#
# ,:
#
# ,
#
#
# UKE:,ENTIO:
#
# , not
# ,
# : the, the,
#
#
# ::
#
# ,, the the,:
#
#
# UKE:,ENTIO:
#
# ,t, the:
#
#
# ::
#
# , the
# ,,
#
#
# UKE:,ENTIO:
#
# ,,
# ,,
#
# ,,,,
# , the king, I, the I,,
#
# ,oth, the,,,,
# , the,, is,,,,,
# ,, the:
# , is,, the,
# , is,,
# ,,,, the
#
# ,,,,
# ,t,
#
# ,,:,
#
# , the
# ,,:
# ,
#
#  the,, my, the king, the,
#
# ,,
# ,,
#
#
# ,, the,
# ,, king,,,, the I,
#
#
# ,:
#
# ,,,,, king,
# ,, the,, the
#  is the,,,
#
#
# UKE:,ENTIO:
#
# ,,,,, the,,,
#
#
#  is,, the,,
#
#
# ::
#
# ,
# ,
# ,
#
#
# UKE:,ENTIO:
#
#  I,
# ,,
# ,:
#  I,,
#
# , be,,:,,
#
#
# ,:
#
# EN,:
# : the,
# , have,,,
# ,,,
#  more,,,,
#
# ,
#  the king,, the,
# ,:, the king,,
# :,, king,
#
# , the,,,,,
#
#
# UKE:,ENTIO:
#
# ,,,,,t,
#
#
# ,:
#
#
# ::
#
# US be,.
#
#
# UKE:,ENTIO:
#
#
# ::
#
# US the,
# ,,
# ,,,,,,
# ,,,
# ,,, the,,,,
# ,,,,
# ,,,
#  the,,,,,,
#
#
# UKE:,ENTIO:
#
# ,:,
#  met,
#
#
# ,:
#
#
# UKE:,ENTIO:
#
# , the I:,:, the the,, the king
# ,,
#
#
# ::
#
# : the,,
# ,,,,, I,
#
#
# , the
# ,,,,
#
#
# UKE:INCENTIO:
#
# ,,, I king,oth,,,,
# ,,, the,,,,,
#  have
# ,,,,, the, the,,
#
#
# ::
#
# ,,,,,,, the.
#  the
#
# ,,
#
# ,
# ,, the king, the,
# ,
# ,, the,,,,,
#
#
# UKE:,ENTIO:
#
# , the,,
#
#
# ::
#
# , the
#  the,, the,
#
#
# UKE:,ENTIO:
#
# EN,,,,,,, the,
#
#
# ,, is the the,
#
#
# ::
#
# :, I,,,,,,, I
# ,
#  the,
# ,
# :
#  the,
# ,,t,
# ,
# , the,
# ,: the
# ,,
#  I,,
#
#
# UKE:INCENTIO:
#
# ,,:
#
#
# ::
#
# :,,,
#  is,,,, king,
# ,
# ,
# ,,, the:,
#  is
# ,,
# ,,:
# ,
# ,,,,
# ,,,,
# , a:,,,.
#  I
#
# ,,, the,
#  I,, the,
# ,,
# Model checkpoint saved to smollm2_checkpoint.pt
# Do you want to load the checkpoint and continue training for 50 steps? (Yes/No): Yes
# <ipython-input-2-b5d29637bcf5>:162: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(checkpoint_path, map_location=device))
# Checkpoint loaded.
# Step 200, Loss: 5.4430131912231445
# Prediction: :
#
# ,
#  to,
# : a I, the,
# , king,
#  I,,,
#
#
# ENIUS:
#
# US be,tis,
#
# US, is be,,
# :
#  the.
# ,
#  I the the
# ,,,
# ,: the,,
#
# , a,,,
#  is,,oth,
#
#  king,
# ,,
#
# , the,
#  I,
# ,,, the king,
#
# :,
#  the,, the,
# , the have a,,
# , the
# ,, the
# ,
#
# ,,IO
#  have a,,,
# ou, the,,morrow,,,
# , have be,,
# :, is the,, be lord,
#
#  I,'ll not, the,
#
#
# OIO:
#
#  have, king,: the
# ,
#
# ,,,
# ,
#
#
# ENRYUS:
#
#
# ,
#  have be,,
#
#  the the is,
#  am bere the,
# ,
#  the lord,
#
#
# :IUS:
#
# ,,,,.
#
#
# ,,IUS:
#
# ,
#
#
#
# IUS:
#
# US the,
#  is,, the,
#
# ,
# , Itis,,,,
#  the
# ,
#  your,, the
# :
# 'll,,,,,
#
#  the,,::,,tisU,
#  the,,,
# ,
#  the
# : the,
# , is,
#
#
# ,: the,,,
# , is not,
#
# , the the, the, the
#
#
#
# , I the, the,
#
# ,
# :,
#
#
# ,
#
# ,
#  I have,
# , the,,
# ,
#  the
# ,
# ,
#  thet,
#
#  I the,,,,,,, the
#
#
# ,:
#
# ,
# ,
# ,
#
#
# ,:
#
# ,
#  the,,
#
#
# ENRYUS:
#
#  have, a,
# tis,,
# ,
#  the
# ,
#
# US, the, the,
#
# ,
#  be, the,:
#
#
#
# ,:
#
# ,,
#
#
# ENIUS:
#
# ,,
#
#
# ::
#
# , be,,
# , be,
#
# ,
# , more, the the,
#
#
# ,:
#
#  have be the
# ,, the,,
# , be, the,,,
#
#
# ENRYUS:
#
# , lord,
#
#  I, a,,,, the,
#
#  I the
# :,
# , the
#  the,,
#
#  lord,
# ,
#
# : is the,,,
#
#
# ,:
#
# : is,
# :,
#  king, the
# ,
#  the,,,,
#
#
# ENRYUS:
#
# US,,
# ,
#
#  the, the lord,
#  will a,
#  the, the
# ,,
# ,, I,
# ,,:,, the
# ,,,
#
#
#  have,,, lord,
#
#  the,,t,
#  the the king: I,,
# ,,,,,
# ,,
# ,
#
# , the
# : the
# ,,
#
# US
# ,,, king,
#  the the
# ,
# ,,,, king,
# ,
# ,
#
# US, a, the,
#
#
# ,:
#
# ,
# ,
#
# ,,, I, the the
#
# ,, I, a,, the
# ,
# ,
# , the,,
#  more
# , is, IIO
# ,: I the,,,,
# ,
# ,,
#
#
# ENRYUS:
#
# ,:,
# ,
# , lord, the,,,
#
# ,,, the king, theEN,
#
#
# ,:
#
# ,,, a
#
# ,
#  I,,,
# ,
#  have a, I
# ,,
# ,
#  be
# ,
# ,,,
# ,
# ,,
#
#
# ENRYUS:
#
# , isoth,
#
# ,,,
#  the'll,,
# , the,
# ,,
#
#
# ,:
#
#  have,
# :
# ,,
#
#
# ENIUS:
#
# US I
#  I
# , the
#
#
# ,:
#
# ,, be,,
#  I is,
# ,,
#
# ,, a,,,, king,
# ,: the,
#  I
#  the man,
#
# ,,,
#
#
# ,
# ,
# , be
# ,
# ,, the king::, the,
# ,
#  king,:
# , the
# ,
# , the
# Step 210, Loss: 5.244290351867676
# Prediction:
#  lord,
#
#  be the lord, the,:
#
#  the the
#  lord,. I,,
#
# EN,,,
# , have,,, the
# ,
#
# ,
# ,,.,,
# ,
#  have,
#
#
# ,IO:
#
# ,,
# ,
# , be'll,
#  the,,,
# :,,,
#
#
# RUKEIO:
#
# ,,
# 'll,
# ,,,,,
#
#
# ,IO:
#
# ,,,,
# ,
# ,
# ,
# ,, have
# ,
#  I
# US be,,,
# ,
#
#
# RUKEIO:
#
# ,,
#  have,
# ,, the, the
# ,,,,
# , have be,,,,t.,
#
#
# ,IO:
#
#  lord, the,,,
#  have you,
# ,,
#
# ,,'ll,,,, the king,
#
#
# RUKEIO:
#
# ,,,,
#
# ,
# ,,
#  the, be,,
# 'll be,,
#
# US be,,,,,
# ,
#  I,,
#
#
# ,IO:
#
# ,
# ,
# ,
#  lord, the,
#
#
# RUKEIO:
#
# ,
# ,, have,,
# ,,,
#
#
# EN,IO:
#
# ,,
# ,t king,
# ,,,,,,
#
# , lord,,,,,
# , you, the the,,
#
#
# RUKEIO:
#
# ,,,,,
# ,, the, king,
#
#  the,,,,,,
# ,,,,
# ,'ll,
#
#
# EN
# IO:
#
# T,,,
# ,,,,,
# ,, you,,,
# ,,,,,,,
# ,.,
# ,
#  have,,
# ,,
#
#
# ,IO:
#
# ay,
# tis,,,
# ,
# , istis,, the,
#
# ,,,, man,, the, the,
#
# ,
# ,,
# ,
#  is,,,, I,
# ,,,
# ,
# .
# , is, the man, the
# ,
# ,,
# ,,
#  the man,'ll the
#
# , the:
#
# ,,
# ,, not be, have,
# ,,, the,
# ,,,,:,, the king,
#
#
# RUKEIO:
#
# :,,
# ,,,,
#
# US,, king,,, the,,
#  I,,,, the lord, the,,
#
#
# UMIO:
#
# ,, the king,
# ,,
# ,,,,
#
# ,,
# tis,,
# ,,,
# ,,,
#
# IO,,.
#  I,,,,,,,,
# , the
# tisIO, the king,,
#
# RUKEIO:
#
# ,,
#  the,
# ,,,
# 'll,,
#
#
# EN,IO:
#
#
# ,,
# ,
#  have you.,,t,
#
# ,
# ,t man,,tis,,,,,
#
# ,.
# ,,
# ,,,,,
#
# , the,,
# .,
# ,,,,
# ,,, be,,, the,,,
#
#
# RUKEIO:
#
#  the
#  I,.,,, king,
#
#  be,
#  the, the the,
#  the,,,
# , the man,
#
# ,,,,,
# ,,, the,
#
# ,,,
#  lord,
#  a,
#
# ,'ll a,, you,,
#
# EN,, the:, I, I,'ll be
#
# ES,, the lord,'ll, the, the,
#
#  I,,,, the the king,
#
#
# EN,IO:
#
# ,,,
#  be have,,,, the,
#  I,, the
# ,,,morrow,,,,
#
# ou,er:,,, I man, the lord,
#
#  I,'ll be,, is be,,
# ,
# ,
#  I,er,,. lord,
#
# , have be the,, the,
#
#
# RUKEIO:
#
# ,,,,,
# tis,
#  a, you have
# :,,
#
# ,
#  you,,
#
# ,, the the,,,t,
#
#  I, the, the lord,,,
#
# ,, I the I,,,,er,
#
# ,, I,,,, I,, I,,
# ,.er
# Step 220, Loss: 5.144100666046143
# Prediction: ,,,,
#
#
#
#  king,
#
# , the,,
# ,,: I king,,
#
#  I,
#  not, man,,,,
#
# ,,, the, the,,,
#
#  I the,
#  have atis,,,,,
#
# , the, a king,morrow,
#
#
#  you:,:
#
# US be,,,, the,,
#
#
# ,O:
#
# EN,
#
# ,,
#  is, is be the,
# ,,,
#
#
# ANUS:
#
#  the is
# ,
# ,,
# ,
# ,, king,
#
#
# RUKEIO:
#
# ,,
# ,
# 'll,, the,
#
#  I,
#  have,,
#  It I the,
#
# eris,,,tis,,,,,
# ,,
#
# , is be, a, thou the,
#
# US you,
# tis I, the,
# ,, is,,
# ,
#  king,,,
#
# ,, the lord:
#  I, the,
# ,,,,,
# ,, the.
#
# , the man,, is,, the,,
#
# :
# ,, more,,
# tis, man, the the
#
# ,,
#  I, I,,,
#
# :,,,:,, a king, thou,,
#
# ,, father,
# ,
# 'll not the,
#
#  have,,tis,, king,morrow:
#
# ost, king,
# ,
#  the, king,
#
# US not a, lord,,, be,,
#
#
# ENT:AB:
#
# US,, I the,
#  I,, grace,
#
# ,,,,
# ,,,
# tis,
# ,
#
#
# ,
# :
#
# :,
# , are
#  have,,,
#
#
# RUKEIO:
#
# ,
#  I,
#
# ,
# ,,
#
# US not the.
# ,,,,
#
# , not,: I,
# ,,
#
#  I,,
# ,
#  have not a,'er:
#
#
# ,O:
#
# ,,,:,,,,,
#
#
# EN,:AB:
#
# ,
# ,
# , have, man,t,
#
#  I,,, the man,
#
#
#
# ANUS:
#
#  the,, man:,,, the,
#
# er
# .,,,
#
# , the king,
#
#
# ENT:AB:
#
#  my,'ll, a
# , the king,
#
#
# ,
# :
#
# ,, I is,, man,:
#
# ,,
# ,:
#  be
# ,,
#
# , the king, have, a, the
#
# US I:,
#  I the:,,
#
#
# ANUS:
#
#  I have,,,,,,,
# ou,,
# ,
#
# ,,,,
#
#
# ,
# :
#
# ,,
#  art, thou,,,, I'll
#
#
# ANIO:
#
# ,,
# ,,oth,:
#
#
# ,
# :
#
# ,ine,oth,,
#
# IC,,
# ,,
# tis,, I, the,,
#
#
# ANUS:
#
# ,. the,er, I,,.:
#
#
# ENT:AB:
#
# ,,
# ,
# 'll not,,,
#
# er:., be, king,
#
#  is the,
#  I,, lord,
# oth,
# all, a lord,,t,
#
# ,
# ,,,,,
# ,,,,,
#
#
# ,
# :
#
# ,
#  I, you
#  lord,, king,
#  the,,, a, the,
#
# ,, there,, the,,,oth,,,
#
#  lord,, the the,,,,,
#
# ,:,'ll a,, lord,,
#
#  the,,, lord,,,,
#
# ,,,
# :
#  I
# ,,
#
# .,
# ,,,., a,
#
# ,, the,, the, not
#
# .,,
# ,
#  the, I,
#  the,,,,
# ,
#  the lord,
# US a man,, youmorrow,, the king
# ,
#
# ,,,,,, the lord,
#
# , the,,, the,,
#
#  lord,,, the,
# 'll I,
#
#  I you have, themorrow,
# , the,
#
#  I,'ll, is not a,,
#
#
#
# US:
#
# ,tis: the,. the
# ,
# ,
# Step 230, Loss: 5.242269039154053
# Prediction: ,,
#
#
# UCIOIO:
#
# , the king, the,, am,
#
# ,t,, I,,,
#
# ,
# ,
# ,
#
#
# ANUS:
#
# ,,
# ,
# ,
#  I, brother,
#
#
# ENT:AB:
#
# AR,,
#  I have be, you to
# ,'ll a,
# ,:
# ,, the
#
#  I me, the,,,
# ,
# ,
#
# , am not,,'er, king,
#  lord,
#
#
# :ARET:
#
# :,,,
# , the,
# :, the king,
#  a is,,
#
#
# ,US:
#
# IC,
# ,, the lord,
#
# ,
#  be the,:, am,
#
#  lord, the, be, lord,
#
# ,, be,
# , the,
#
#
# UCIOIO:
#
# EN,
# ,,,
# , bet,,,,
#
#
# EN,IO:
#
# ,,,,
#  not, a,,
#
# ,, am IUS, not,
# EN,,t,
#
#
# ,O:
#
# , be,,,,,
#
# ,,,,
#  the,,, the,
#
#  I a, the king,, the,,
#
#
# ENTisAB:
#
# AR,,
# ,,
#  have I:
#
# , the
# ,:
#
#  I the have,,
# ,,,,
# ,,
# : the,
#
#
# , not'll,, lord,
#
#
#  the,,,
#
# ,
# ,,,
#
# ,:,:,,
# ,
# ,, a
#
#  you,,,
#  the the
# ,
# US not the:,
#  I,
#  the,,, the to,,
#
#  I,,
# ,,,
# , be,
#
# , have I, be the, a,,
#
#
# .ARET:
#
# ,
#  the have, have,,,
#  be am,
# ,
#
# , have a the,
#  I,
# ,,
#  have
# ,,, I be the I I the,
# ,
#
#
# ,O:
#
# , be, the king,t,
#  honour,,,
# ,
# ,t, not the,
# EN, the,
# ,,
# ,,,
#  I have be,
# :
# ,
#  the,,,,
#  brother,: the
# ,,
# ,,
# , the king, have the lord
# ,,,
#  you am the the,,, the man,
# : be the,,,
#  the,
#  have not
# ,,, be,,
#
#
# EN,,:
#
# , not have
# ,,:,,
#  I man,
#  have,
#
#  I king, the king,,,,,
# ,,
# ,,
#  the:
#  is, the,,,
#
# , have be the, a, the,,
# ,: the the,
#  the the,t,
#  the
# ,, I,,,,
#
#
#  theO:
#
# ,t I
#  have,
#
#
# EN,IO:
#
#
# ,
# ,
#  the, man, the,,
#
#
# ,O:
#
# :,
#  man,
#
#
# EN,IO:
#
# US,
#  man,
#
#
# ,O:
#
# US,
#  man,
# .,,
# ,,,
#  I
# ,, the,,
#  the, the,, man,
# , a, the,
#
#
# EN,IO:
#
# is,
# :,,
#  I is, grace, the,
# ,,,,,,,
# ,
# ,
# , so not
# ,, the king,
# US man,,, the,
#
# , the, a the,
#  the you,
#
#
# ,O:
#
# US, the
#  a have, I,
# ,,,, a
# ,,
#  the a, the king,,
# :,
#
#
# EN,IO:
#
# ,
#  I have,
# ,t,, the,
#  the,
#
# ,
# , is, the,,,
# ,
# , be the,,,,
# , of,, the the,,t,,
# , man, have,
# ,, the man,
#
# ,, a be, man,
# ,
# ,
# ,,
# ,
# ,,
# , I,,, king not
#
# ,,,
# :, of,,
#
#
# ,O:
#
# US a,
#  I not have the,, world,
# , the,, the,,,, I
# Step 240, Loss: 5.423511981964111
# Prediction:
#
# ,
#
# , me,,
#  will,, the thou the,
#
# ,,
# ,
# ,
#  have a,,
#
# ,,
#  lord,
# ,
#
#
# ,O
#
# :,
#
# ,
# ,,
# ,
#  am,
#  have,,,,
# ,, the,
#
#  be,
#  the, a king,
#  the,
# , king,
# ,
#  the father,,,
# ::
#  the father,
#
#
# ,,O:
#
# EN, art
# ,
#
# ,,, the, king,, I'll
# ,,
#
#
# ::
#
#  the
# ,
#
# US, king,t,
# , the king a,
#
# , the king,
#  king,
#  the,,
#
# US,:,,
# , haveer:,
#
# ,, the,,
#  the king,,
#
#  king, the,,:
#  not am,
#
#
# ,, the,
# ,,t,,
#  king the,,
# : the king,,morrow,,
# ,,,
# ,,morrow,,, the
#  king, the,
#  the
# ,, king,,,
# ,, the,, the the
# ,:,,
#
# :,
#  the,:,,
#
#
# ,,O:
#
#  lord,,
#
# , the,,
# ,,
#  I,:
# ,,,
# ,
#
#
# ,O
#
# , man,
# ,, man, the king, the,,
# ,, the:
# . I,,
#  the,, the king,,,,
# , king,
#
# , the man, the,
#  king,t,
# ,
#
#  the,,morrow,,
#
# , a,,
# ,,
#
#
#
#  king,, I,
#
# ,
# tis, the,
#
#  the king,,,
#
#
# ,,O:
#
# , It lord,
#
# , the the,,,,
#
#
# ,O
#
# , the
#  lord,
#
#
# :,O:
#
# ,, have
# ,
# ,
#
#
# :O
#
# , man,,,
#
# ,
#  of of, man:,,
#
# ,,, the the
#  my
#  the hast,,,
#
# ,, have a,,tis
# , king the,
#
#  king,t, a have, the,
#
# C, have,: the king, the,,
#  the,,, the king the, the me
#
# C, the is,:
#
#
# ,,O:
#
#  the king,t,
# ,,:, the, a,
#  I, king,'er king,
#
#
# ,O
#
# ,, the,
# , king,t,
#  the king,,:
# ,,
# ou,,, thou,, the, be,,,
# , king,morrow:,
# ,,,
# , ist:
#
#  king,: the
# ,,::
#
#
# ,
#  the man,,
#  the
# ,
# ,
#
# US a,:
#  the the king,'T king,
# ,'ll,
# , the the,,
# , you the king,:,
#
# ,,, the,
#
# ,, I have
#  king,t,,,
# , a,,,
#
#
# ,,O:
#
# ::
#
#
#
# , the,
#
#
# ,t,,
#
# , the king,'T king,
#
#
# ,O
#
# , king,,
#
#
# ,,O:
#
# ,,,,
# ,,tis,,, the,
# , the,, the,, the,
#
#
# ,O
#
#  the's, the,
# ,,oth:,,,
#
#  me,,,, art a,
#
#  a the,,,
# ,
#
#
# ,,O:
#
# ,,
# ,,
#
# , the, art be,,
#
#
# ,O
#
#  lord,
#
#
# ,
# O:
#
# , king,,,
#  more,
#
#
# ,:
#
# US's,,
#
# : have a,,,,
#
# is,, more the
# ,, more,,
# ,
# ,
# :, the,:
#
# ,, thou,
#  the,:, man of,
#
#
# ,,O:
#
# U:,,
#  the I man, am,,,
#
#
# ,O
#
# ,
#
#
# :
# O:
#
# an
# oth:
#  the,t, is, the, king',,
#  the king,,
#
#  the, the king:,
# Model checkpoint updated and saved to smollm2_checkpoint.pt
